# %%
from alpha_vantage.timeseries import TimeSeries
import json
import pandas as pd
from sklearn import preprocessing
import numpy as np

# %%
data = pd.read_csv('CPALL.csv')
data = data.dropna()
data = data[data['Vol.'] != '-'] # drop the rows which contain '-' value
data['Vol.'] = data['Vol.'].replace({'M':'*1e6', 'K': '*1e3'}, regex=True).map(pd.eval).astype(int)
data['Change %'] = data['Change %'].replace({'%':'*1'}, regex=True).map(pd.eval).astype(float)
data.drop('Date', axis=1, inplace = True)
data = data.drop(0, axis=0)
data.sort_index(ascending=False, inplace = True, ignore_index=True)
data.head(3360)
# Out:
#       Price   Open   High    Low      Vol.  Change %
# 0      3.17   3.15   3.17   3.12    905800      0.63
# 1      3.23   3.15   3.30   3.15   5010000      1.89
# 2      3.10   3.25   3.27   3.08   4620000     -4.02
# 3      3.12   3.10   3.20   3.10   2040000      0.65
# 4      3.08   3.05   3.10   3.05   7900000     -1.28
# ...     ...    ...    ...    ...       ...       ...
# 3340  63.75  63.50  64.25  63.25  18750000      0.39
# 3341  63.50  64.00  64.50  63.50  18920000     -0.39
# 3342  63.50  64.00  64.75  63.25  24080000      0.00
# 3343  63.00  63.25  63.50  62.75  23060000     -0.79
# 3344  64.00  63.00  64.00  62.75  21880000      1.59
#
# [3345 rows x 6 columns]

# %%
data_normaliser = preprocessing.MinMaxScaler()
data_normalised = data_normaliser.fit_transform(data)
history_points = 50
ohlcv_histories_normalised = np.array([data_normalised[i  : i + history_points].copy() for i in range(len(data_normalised) - history_points)])
next_day_open_values_normalised = np.array([data_normalised[:,1][i + history_points].copy() for i in range(len(data_normalised) - history_points)])
next_day_open_values_normalised = np.expand_dims(next_day_open_values_normalised, -1)

# %%
data = np.asanyarray(data)
next_day_open_values = np.array([data[:,1][i + history_points].copy() for i in range(len(data) - history_points)])
next_day_open_values = np.expand_dims(next_day_open_values_normalised, -1)

# %%
next_day_open_values
# Out:
# array([[[0.        ]],
#
#        [[0.        ]],
#
#        [[0.        ]],
#
#        ...,
#
#        [[0.70987583]],
#
#        [[0.7011721 ]],
#
#        [[0.69827086]]])

# %%
next_day_open_values.reshape(3295,1)
# Out:
# array([[0.        ],
#        [0.        ],
#        [0.        ],
#        ...,
#        [0.70987583],
#        [0.7011721 ],
#        [0.69827086]])

# %%
y_normaliser = preprocessing.MinMaxScaler()
y_normaliser.fit(next_day_open_values.reshape((3295,1)))
y_normaliser.transform(next_day_open_values) # Indicate the values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-261-3a505ca74b54> in <module>
#       1 y_normaliser = preprocessing.MinMaxScaler()
#       2 y_normaliser.fit(next_day_open_values.reshape((3295,1)))
# ----> 3 y_normaliser.transform(next_day_open_values) # Indicate the values
#
# E:\Anaconda\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X)
#     405         check_is_fitted(self)
#     406
# --> 407         X = check_array(X, copy=self.copy, dtype=FLOAT_DTYPES,
#     408                         force_all_finite="allow-nan")
#     409
#
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     639             array = array.astype(np.float64)
#     640         if not allow_nd and array.ndim >= 3:
# --> 641             raise ValueError("Found array with dim %d. %s expected <= 2."
#     642                              % (array.ndim, estimator_name))
#     643
#
# ValueError: Found array with dim 3. Estimator expected <= 2.

# %%
next_day_open_values
# Out:
# array([[69.75],
#        [69.75],
#        [70.5 ],
#        ...,
#        [ 3.25],
#        [ 3.15],
#        [ 3.15]])

# %%
test_split = 0.9
n = int(ohlcv_histories_normalised.shape[0] * test_split)

# %%
ohlcv_train = ohlcv_histories_normalised[:n]
y_train = next_day_open_values_normalised[:n]
ohlcv_test = ohlcv_histories_normalised[n:]
y_test = next_day_open_values_normalised[n:]

unscaled_y_test = next_day_open_values[n:]

# %%
ohlcv_train.shape
# Out:
# (2965, 50, 6)

# %%
import keras
import tensorflow as tf
from keras.models import Model
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate
from keras import optimizers
import numpy as np
np.random.seed(4)
# from tensorflow import set_random_seed
# set_random_seed(4)
import tensorflow
tensorflow.random.set_seed(4)
# Solve pydot problems
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

lstm_input = Input(shape=(history_points, 6), name='lstm_input')
x = LSTM(50, name='lstm_0')(lstm_input)
x = Dropout(0.2, name='lstm_dropout_0')(x)
x = Dense(64, name='dense_0')(x)
x = Activation('sigmoid', name='sigmoid_0')(x)
x = Dense(1, name='dense_1')(x)
output = Activation('linear', name='linear_output')(x)
model = Model(inputs=lstm_input, outputs=output)

adam = optimizers.Adam(lr=0.0005)

model.compile(optimizer=adam, loss='mse')

#from keras.utils import plot_model
#plot_model(model, to_file='model.png')

# %%
model.fit(x=ohlcv_train, y=y_train, batch_size=64, epochs=100, shuffle=True, validation_split=0.1)
evaluation = model.evaluate(ohlcv_test, y_test)
print(evaluation)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 21ms/step - loss: 3.8563e-04 - val_loss: 1.3996e-04
# Epoch 2/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.7757e-04 - val_loss: 3.7478e-04
# Epoch 3/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.5030e-04 - val_loss: 3.1240e-04
# Epoch 4/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.3737e-04 - val_loss: 1.1891e-04
# Epoch 5/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.8335e-04 - val_loss: 2.8575e-04
# Epoch 6/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.6256e-04 - val_loss: 1.5164e-04
# Epoch 7/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.9229e-04 - val_loss: 1.2951e-04
# Epoch 8/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.5721e-04 - val_loss: 2.1439e-04
# Epoch 9/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.5564e-04 - val_loss: 1.7502e-04
# Epoch 10/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.4554e-04 - val_loss: 5.0736e-04
# Epoch 11/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.9196e-04 - val_loss: 2.5572e-04
# Epoch 12/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.4962e-04 - val_loss: 2.2449e-04
# Epoch 13/100
# 42/42 [==============================] - ETA: 0s - loss: 3.6557e-0 - 1s 19ms/step - loss: 3.6154e-04 - val_loss: 1.3368e-04
# Epoch 14/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.3065e-04 - val_loss: 2.0085e-04
# Epoch 15/100
# 42/42 [==============================] - 1s 18ms/step - loss: 4.2077e-04 - val_loss: 3.4544e-04
# Epoch 16/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.4047e-04 - val_loss: 3.1639e-04
# Epoch 17/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.5131e-04 - val_loss: 2.4211e-04
# Epoch 18/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.4410e-04 - val_loss: 2.0423e-04
# Epoch 19/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.3967e-04 - val_loss: 3.5822e-04
# Epoch 20/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3
100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.4674e-04 - val_loss: 1.0032e-04
# Epoch 52/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.8432e-04 - val_loss: 1.0476e-04
# Epoch 53/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.6796e-04 - val_loss: 1.3811e-04
# Epoch 54/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.4727e-04 - val_loss: 1.3273e-04
# Epoch 55/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.5116e-04 - val_loss: 4.5372e-04
# Epoch 56/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.2635e-04 - val_loss: 1.9032e-04
# Epoch 57/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.1804e-04 - val_loss: 9.6836e-05
# Epoch 58/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.2817e-04 - val_loss: 1.1934e-04
# Epoch 59/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.6263e-04 - val_loss: 3.9948e-04
# Epoch 60/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.6102e-04 - val_loss: 1.6540e-04
# Epoch 61/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.3463e-04 - val_loss: 3.0428e-04
# Epoch 62/100
# 42/42 [==============================] - 1s 22ms/step - loss: 3.2722e-04 - val_loss: 9.5060e-05
# Epoch 63/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.5243e-04 - val_loss: 1.1015e-04
# Epoch 64/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.4850e-04 - val_loss: 2.1572e-04
# Epoch 65/100
# 42/42 [==============================] - 1s 21ms/step - loss: 3.5347e-04 - val_loss: 8.2808e-05
# Epoch 66/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.5346e-04 - val_loss: 2.9811e-04
# Epoch 67/100
# 42/42 [==============================] - 1s 22ms/step - loss: 3.5518e-04 - val_loss: 7.3188e-05
# Epoch 68/100
# 42/42 [==============================] - 1s 21ms/step - loss: 3.4187e-04 - val_loss: 6.9311e-05
# Epoch 69/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.5210e-04 - val_loss: 7.6707e-04
# Epoch 70/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.7030e-04 - val_loss: 2.2738e-04
# Epoch 71/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.4988e-04 - val_loss: 4.3867e-04
# Epoch 72/100
# 42/42 [==============================] - 1s 24ms/step - loss: 3.6165e-04 - val_loss: 1.2204e-04
# Epoch 73/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.7688e-04 - val_loss: 2.7741e-04
# Epoch 74/100
# 42/42 [==============================] - 1s 21ms/step - loss: 3.4889e-04 - val_loss: 8.4724e-05
# Epoch 75/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.8261e-04 - val_loss: 8.3691e-05
# Epoch 76/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.6221e-04 - val_loss: 2.3303e-04
# Epoch 77/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.7178e-04 - val_loss: 3.6701e-04
# Epoch 78/100
# 42/42 [==============================] - 1s 22ms/step - loss: 3.4729e-04 - val_loss: 7.8240e-05
# Epoch 79/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.1690e-04 - val_loss: 7.8657e-05
# Epoch 80/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.4616e-04 - val_loss: 1.5434e-04
# Epoch 81/100
# 42/42 [==============================] - 1s 26ms/step - loss: 3.8554e-04 - val_loss: 7.2518e-05
# Epoch 82/100
# 42/42 [==============================] - 1s 24ms/step - loss: 3.7553e-04 - val_loss: 1.7769e-04
# Epoch 83/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.6480e-04 - val_loss: 1.1961e-04
# Epoch 84/100
# 42/42 [==============================] - 1s 23ms/step - loss: 3.5555e-04 - val_loss: 6.5110e-05
# Epoch 85/100
# 42/42 [==============================] - 1s 21ms/step - loss: 3.2814e-04 - val_loss: 6.4616e-05
# Epoch 86/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.9986e-04 - val_loss: 1.0208e-04
# Epoch 87/100
# 42/42 [==============================] - 1s 23ms/step - loss: 3.3338e-04 - val_loss: 6.3335e-05
# Epoch 88/100
# 42/42 [==============================] - 1s 26ms/step - loss: 3.6411e-04 - val_loss: 1.6079e-04
# Epoch 89/100
# 42/42 [==============================] - 1s 28ms/step - loss: 3.7195e-04 - val_loss: 1.3476e-04
# Epoch 90/100
# 42/42 [==============================] - 1s 23ms/step - loss: 3.5447e-04 - val_loss: 1.0545e-04
# Epoch 91/100
# 42/42 [==============================] - 1s 23ms/step - loss: 3.7108e-04 - val_loss: 2.7750e-04
# Epoch 92/100
# 42/42 [==============================] - 1s 21ms/step - loss: 3.4373e-04 - val_loss: 7.8180e-05
# Epoch 93/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.4593e-04 - val_loss: 1.1574e-04
# Epoch 94/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.2910e-04 - val_loss: 2.4500e-04
# Epoch 95/100
# 42/42 [==============================] - 1s 22ms/step - loss: 3.6717e-04 - val_loss: 1.3415e-04
# Epoch 96/100
# 42/42 [==============================] - 1s 21ms/step - loss: 3.8185e-04 - val_loss: 1.3709e-04
# Epoch 97/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.3108e-04 - val_loss: 5.8809e-05
# Epoch 98/100
# 42/42 [==============================] - 1s 19ms/step - loss: 3.7938e-04 - val_loss: 5.1887e-04
# Epoch 99/100
# 42/42 [==============================] - 1s 18ms/step - loss: 3.4491e-04 - val_loss: 2.0688e-04
# Epoch 100/100
# 42/42 [==============================] - 1s 20ms/step - loss: 3.4515e-04 - val_loss: 1.2631e-04
# 11/11 [==============================] - 0s 5ms/step - loss: 1.5447e-04
# 0.00015447150508407503

# %%
y_test_predicted = model.predict(ohlcv_test) # model.predict returns normalised values
# now we scale them back using the y_scaler from before
y_test_predicted = y_normaliser.inverse_transform(y_test_predicted)

# also getting predictions for the entire dataset, just to see how it performs
y_predicted = model.predict(ohlcv_histories_normalised)
y_predicted = y_normaliser.inverse_transform(y_predicted)

# %%
assert unscaled_y_test.shape == y_test_predicted.shape
real_mse = np.mean(np.square(unscaled_y_test - y_test_predicted))
scaled_mse = real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
print(scaled_mse)
# Out:
# 36.49818149239515

# %%
import matplotlib.pyplot as plt
plt.gcf().set_size_inches(22, 15, forward=True)

start = 0
end = -1

real = plt.plot(unscaled_y_test[start:end], label='real')
pred = plt.plot(y_test_predicted[start:end], label='predicted')

plt.legend(['Real', 'Predicted'])
plt.ylim([2, 20]) 
plt.show()

# %%
plt.gcf().set_size_inches(22, 15, forward=True)

start = 0
end = -1

real = plt.plot(next_day_open_values[start:end], label='real')
pred = plt.plot(y_predicted[start:end], label='predicted')

plt.legend(['Real', 'Predicted'])

plt.show()
